# %% [markdown]
# # Predicción del precio del aguacate por medio de regresion linear multiple

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import (mean_squared_error, r2_score, accuracy_score,
                             confusion_matrix, classification_report,
                             f1_score, precision_score, recall_score,
                             roc_curve, roc_auc_score)
from sklearn.preprocessing import StandardScaler


df = pd.read_csv('../data/avocado_clean.csv')
df.head()
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 17934 entries, 0 to 17933
# Data columns (total 66 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   AveragePrice                17934 non-null  float64
#  1   Total Volume                17934 non-null  float64
#  2   4046                        17934 non-null  float64
#  3   4225                        17934 non-null  float64
#  4   4770                        17934 non-null  float64
#  5   Total Bags                  17934 non-null  float64
#  6   Small Bags                  17934 non-null  float64
#  7   Large Bags                  17934 non-null  float64
#  8   XLarge Bags                 17934 non-null  float64
#  9   day                         17934 non-null  int64
#  10  week                        17934 non-null  int64
#  11  month                       17934 non-null  int64
#  12  type_ORGANIC                17934 non-null  float64
#  13  region_ATLANTA              17934 non-null  float64
#  14  region_BALTIMOREWASHINGTON  17934 non-null  float64
#  15  region_BOISE                17934 non-null  float64
#  16  region_BOSTON               17934 non-null  float64
#  17  region_BUFFALOROCHESTER     17934 non-null  float64
#  18  region_CALIFORNIA           17934 non-null  float64
#  19  region_CHARLOTTE            17934 non-null  float64
#  20  region_CHICAGO              17934 non-null  float64
#  21  region_CINCINNATIDAYTON     17934 non-null  float64
#  22  region_COLUMBUS             17934 non-null  float64
#  23  region_DALLASFTWORTH        17934 non-null  float64
#  24  region_DENVER               17934 non-null  float64
#  25  region_DETROIT              17934 non-null  float64
#  26  region_GRANDRAPIDS          17934 non-null  float64
#  27  region_GREATLAKES           17934 non-null  float64
#  28  region_HARRISBURGSCRANTON   17934 non-null  float64
#  29  region_HARTFORDSPRINGFIELD  17934 non-null  float64
#  30  region_HOUSTON              17934 non-null  float64
#  31  region_INDIANAPOLIS         17934 non-null  float64
#  32  region_JACKSONVILLE         17934 non-null  float64
#  33  region_LASVEGAS             17934 non-null  float64
#  34  region_LOSANGELES           17934 non-null  float64
#  35  region_LOUISVILLE           17934 non-null  float64
#  36  region_MIAMIFTLAUDERDALE    17934 non-null  float64
#  37  region_MIDSOUTH             17934 non-null  float64
#  38  region_NASHVILLE            17934 non-null  float64
#  39  region_NEWORLEANSMOBILE     17934 non-null  float64
#  40  region_NEWYORK              17934 non-null  float64
#  41  region_NORTHEAST            17934 non-null  float64
#  42  region_NORTHERNNEWENGLAND   17934 non-null  float64
#  43  region_ORLANDO              17934 non-null  float64
#  44  region_PHILADELPHIA         17934 non-null  float64
#  45  region_PHOENIXTUCSON        17934 non-null  float64
#  46  region_PITTSBURGH           17934 non-null  float64
#  47  region_PLAINS               17934 non-null  float64
#  48  region_PORTLAND             17934 non-null  float64
#  49  region_RALEIGHGREENSBORO    17934 non-null  float64
#  50  region_RICHMONDNORFOLK      17934 non-null  float64
#  51  region_ROANOKE              17934 non-null  float64
#  52  region_SACRAMENTO           17934 non-null  float64
#  53  region_SANDIEGO             17934 non-null  float64
#  54  region_SANFRANCISCO         17934 non-null  float64
#  55  region_SEATTLE              17934 non-null  float64
#  56  region_SOUTHCAROLINA        17934 non-null  float64
#  57  region_SOUTHCENTRAL         17934 non-null  float64
#  58  region_SOUTHEAST            17934 non-null  float64
#  59  region_SPOKANE              17934 non-null  float64
#  60  region_STLOUIS              17934 non-null  float64
#  61  region_SYRACUSE             17934 non-null  float64
#  62  region_TAMPA                17934 non-null  float64
#  63  region_TOTALUS              17934 non-null  float64
#  64  region_WEST                 17934 non-null  float64
#  65  region_WESTTEXNEWMEXICO     17934 non-null  float64
# dtypes: float64(63), int64(3)
# memory usage: 9.0 MB

# %% [markdown]
# ## Empezamos comprobobando que columnas tienen buena relación entre ellas mediante una matriz de correlación

# %%
plt.figure(figsize=(8, 6))
numeric_cols = ['AveragePrice','Total Volume', '4046', '4225', '4770',
                'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type_ORGANIC']
sns.heatmap(df[numeric_cols].corr(), annot=True, cmap='coolwarm', center=0, fmt='.2f')
plt.title('Matriz de Correlación — Dataset Clean_avocado')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Aqui podemos evidenciar que la vas variables de volumen están altamente correlacionadas entre ellas al igual que las bolsas pero ninguna se relaciona bien con el precio y por el analisis previo sabemos que aunque no se evidencia aqui el tipo de aguacate esta relacionado con el precio asi que haremos varias pruebas para encontrar la mejor combinación de variables

# %% [markdown]
# ## Preparamos los datos y y partimos el Train/Test
# ### para estas primera prueba utilizaremos todas las variables de volumen

# %%
region_dummies = [col for col in df.columns if col.startswith('region_')]

X_reg = df[['type_ORGANIC','Total Volume', '4046', '4225', '4770','month','week'] 
    + list(region_dummies)]
y_reg = df['AveragePrice']

# Dividir en entrenamiento (70%) y prueba (30%)
X_train_reg, X_test_reg, y_train_reg, y_test_reg = train_test_split(
    X_reg, y_reg, test_size=0.3, random_state=42
)

print(f"Datos de entrenamiento: {X_train_reg.shape}")
print(f"Datos de prueba: {X_test_reg.shape}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 3
#       1 region_dummies = [col for col in df.columns if col.startswith('region_')]
#       2
# ----> 3 X_reg = df[['type_ORGANIC','Total Volume', '4046', '4225', '4770','month','year']
#       4     + list(region_dummies)]
#       5 y_reg = df['AveragePrice']
#       6
#
# File ~/Programación/CienciasDatos/Proyecto#2/Avocado_Price_Prediction/.venv/lib/python3.12/site-packages/pandas/core/frame.py:4384, in DataFrame.__getitem__(self, key)
#    4380                 indexer = [indexer]
#    4381         else:
#    4382             if is_iterator(key):
#    4383                 key = list(key)
# -> 4384             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4385
#    4386         # take() does not accept boolean indexers
#    4387         if getattr(indexer, "dtype", None) == bool:
#
# File ~/Programación/CienciasDatos/Proyecto#2/Avocado_Price_Prediction/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
#    6300     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6302 self._raise_if_missing(keyarr, indexer, axis_name)
#    6304 keyarr = self.take(indexer)
#    6305 if isinstance(key, Index):
#    6306     # GH 42790 - Preserve name from an Index
#
# File ~/Programación/CienciasDatos/Proyecto#2/Avocado_Price_Prediction/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:6355, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6352     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6354 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6355 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['year'] not in index"

# %%
modelo_reg = LinearRegression()
modelo_reg.fit(X_train_reg, y_train_reg)

# Predecir sobre el conjunto de prueba
y_pred_reg = modelo_reg.predict(X_test_reg)

print(f"Coeficientes: {modelo_reg.coef_}")
print(f"Intercepto: {modelo_reg.intercept_:.4f}")
print(f"\nInterpretación:")
for col, coef in zip(X_reg.columns, modelo_reg.coef_):
    print(f"  {col}: {coef:+.4f} (por cada unidad de aumento, AvegarePrice cambia en {coef:+.4f})")
# Out:
# Coeficientes: [-0.3872747  -1.39374758  0.15896811  0.32604078 -0.10089137  0.05348742
#  -0.00523126  0.06806912  0.93243121 -0.5241883   0.82939498  0.22402576
#   1.40238341  0.55522863  0.95284842 -0.25220015 -0.40338399 -0.13152061
#   0.24417478  0.010747   -0.03473566  1.10739801  0.43611624  1.13461911
#  -0.09056103 -0.40378219  0.13063819 -0.02169077  0.67192671 -0.61141981
#   0.2538278   1.28778504 -0.37672411 -0.12669682  1.64765356  1.89804517
#   0.73395242  0.37789407  0.84580699 -0.01893647 -0.20491364  1.02867972
#   0.25191171  0.5007914  -0.13862352 -0.49302107  0.66610697  0.28884498
#   1.1975633   0.56512423  0.22191912  0.6319724   1.22851723 -0.42261803
#   0.00287609 -0.07270065  0.10959264  2.11845542  1.25596011  0.11057852]
# Intercepto: -0.4030
#
# Interpretación:
#   type_ORGANIC: -0.3873 (por cada unidad de aumento, AvegarePrice cambia en -0.3873)
#   Total Volume: -1.3937 (por cada unidad de aumento, AvegarePrice cambia en -1.3937)
#   4046: +0.1590 (por cada unidad de aumento, AvegarePrice cambia en +0.1590)
#   4225: +0.3260 (por cada unidad de aumento, AvegarePrice cambia en +0.3260)
#   4770: -0.1009 (por cada unidad de aumento, AvegarePrice cambia en -0.1009)
#   month: +0.0535 (por cada unidad de aumento, AvegarePrice cambia en +0.0535)
#   week: -0.0052 (por cada unidad de aumento, AvegarePrice cambia en -0.0052)
#   region_ATLANTA: +0.0681 (por cada unidad de aumento, AvegarePrice cambia en +0.0681)
#   region_BALTIMOREWASHINGTON: +0.9324 (por cada unidad de aumento, AvegarePrice cambia en +0.9324)
#   region_BOISE: -0.5242 (por cada unidad de aumento, AvegarePrice cambia en -0.5242)
#   region_BOSTON: +0.8294 (por cada unidad de aumento, AvegarePrice cambia en +0.8294)
#   region_BUFFALOROCHESTER: +0.2240 (por cada unidad de aumento, AvegarePrice cambia en +0.2240)
#   region_CALIFORNIA: +1.4024 (por cada unidad de aumento, AvegarePrice cambia en +1.4024)
#   region_CHARLOTTE: +0.5552 (por cada unidad de aumento, AvegarePrice cambia en +0.5552)
#   region_CHICAGO: +0.9528 (por cada unidad de aumento, AvegarePrice cambia en +0.9528)
#   region_CINCINNATIDAYTON: -0.2522 (por cada unidad de aumento, AvegarePrice cambia en -0.2522)
#   region_COLUMBUS: -0.4034 (por cada unidad de aumento, AvegarePrice cambia en -0.4034)
#   region_DALLASFTWORTH: -0.1315 (por cada unidad de aumento, AvegarePrice cambia en -0.1315)
#   region_DENVER: +0.2442 (por cada unidad de aumento, AvegarePrice cambia en +0.2442)
#   region_DETROIT: +0.0107 (por cada unidad de aumento, AvegarePrice cambia en +0.0107)
#   region_GRANDRAPIDS: -0.0347 (por cada unidad de aumento, AvegarePrice cambia en -0.0347)
#   region_GREATLAKES: +1.1074 (por cada unidad de aumento, AvegarePrice cambia en +1.1074)
#   region_HARRISBURGSCRANTON: +0.4361 (por cada unidad de aumento, AvegarePrice cambia en +0.4361)
#   region_HARTFORDSPRINGFIELD: +1.1346 (por cada unidad de aumento, AvegarePrice cambia en +1.1346)
#   region_HOUSTON: -0.0906 (por cada unidad de aumento, AvegarePrice cambia en -0.0906)
#   region_INDIANAPOLIS: -0.4038 (por cada unidad de aumento, AvegarePrice cambia en -0.4038)
#   region_JACKSONVILLE: +0.1306 (por cada unidad de aumento, AvegarePrice cambia en +0.1306)
#   region_LASVEGAS: -0.0217 (por cada unidad de aumento, AvegarePrice cambia en -0.0217)
#   region_LOSANGELES: +0.6719 (por cada unidad de aumento, AvegarePrice cambia en +0.6719)
#   region_LOUISVILLE: -0.6114 (por cada unidad de aumento, AvegarePrice cambia en -0.6114)
#   region_MIAMIFTLAUDERDALE: +0.2538 (por cada unidad de aumento, AvegarePrice cambia en +0.2538)
#   region_MIDSOUTH: +1.2878 (por cada unidad de aumento, AvegarePrice cambia en +1.2878)
#   region_NASHVILLE: -0.3767 (por cada unidad de aumento, AvegarePrice cambia en -0.3767)
#   region_NEWORLEANSMOBILE: -0.1267 (por cada unidad de aumento, AvegarePrice cambia en -0.1267)
#   region_NEWYORK: +1.6477 (por cada unidad de aumento, AvegarePrice cambia en +1.6477)
#   region_NORTHEAST: +1.8980 (por cada unidad de aumento, AvegarePrice cambia en +1.8980)
#   region_NORTHERNNEWENGLAND: +0.7340 (por cada unidad de aumento, AvegarePrice cambia en +0.7340)
#   region_ORLANDO: +0.3779 (por cada unidad de aumento, AvegarePrice cambia en +0.3779)
#   region_PHILADELPHIA: +0.8458 (por cada unidad de aumento, AvegarePrice cambia en +0.8458)
#   region_PHOENIXTUCSON: -0.0189 (por cada unidad de aumento, AvegarePrice cambia en -0.0189)
#   region_PITTSBURGH: -0.2049 (por cada unidad de aumento, AvegarePrice cambia en -0.2049)
#   region_PLAINS: +1.0287 (por cada unidad de aumento, AvegarePrice cambia en +1.0287)
#   region_PORTLAND: +0.2519 (por cada unidad de aumento, AvegarePrice cambia en +0.2519)
#   region_RALEIGHGREENSBORO: +0.5008 (por cada unidad de aumento, AvegarePrice cambia en +0.5008)
#   region_RICHMONDNORFOLK: -0.1386 (por cada unidad de aumento, AvegarePrice cambia en -0.1386)
#   region_ROANOKE: -0.4930 (por cada unidad de aumento, AvegarePrice cambia en -0.4930)
#   region_SACRAMENTO: +0.6661 (por cada unidad de aumento, AvegarePrice cambia en +0.6661)
#   region_SANDIEGO: +0.2888 (por cada unidad de aumento, AvegarePrice cambia en +0.2888)
#   region_SANFRANCISCO: +1.1976 (por cada unidad de aumento, AvegarePrice cambia en +1.1976)
#   region_SEATTLE: +0.5651 (por cada unidad de aumento, AvegarePrice cambia en +0.5651)
#   region_SOUTHCAROLINA: +0.2219 (por cada unidad de aumento, AvegarePrice cambia en +0.2219)
#   region_SOUTHCENTRAL: +0.6320 (por cada unidad de aumento, AvegarePrice cambia en +0.6320)
#   region_SOUTHEAST: +1.2285 (por cada unidad de aumento, AvegarePrice cambia en +1.2285)
#   region_SPOKANE: -0.4226 (por cada unidad de aumento, AvegarePrice cambia en -0.4226)
#   region_STLOUIS: +0.0029 (por cada unidad de aumento, AvegarePrice cambia en +0.0029)
#   region_SYRACUSE: -0.0727 (por cada unidad de aumento, AvegarePrice cambia en -0.0727)
#   region_TAMPA: +0.1096 (por cada unidad de aumento, AvegarePrice cambia en +0.1096)
#   region_TOTALUS: +2.1185 (por cada unidad de aumento, AvegarePrice cambia en +2.1185)
#   region_WEST: +1.2560 (por cada unidad de aumento, AvegarePrice cambia en +1.2560)
#   region_WESTTEXNEWMEXICO: +0.1106 (por cada unidad de aumento, AvegarePrice cambia en +0.1106)

# %% [markdown]
# ## Tabla comparativa

# %%
df_pred_reg = pd.DataFrame({
    'Actual': y_test_reg.values, 
    'Predicho': y_pred_reg.round(2), 
    'Error': (y_test_reg.values - y_pred_reg).round(4)
})
df_pred_reg.head(10)
# Out:
#      Actual  Predicho   Error
# 0  0.944418      1.13 -0.1859
# 1  0.021696      0.21 -0.1900
# 2  0.601692      0.53  0.0691
# 3 -0.452846     -0.46  0.0047
# 4 -0.848298     -0.71 -0.1387
# 5 -0.321029     -0.42  0.0958
# 6  1.656231      1.44  0.2160
# 7 -1.006479     -0.64 -0.3627
# 8 -1.586476     -1.05 -0.5377
# 9  1.366233      1.72 -0.3529

# %% [markdown]
# ## Evaluación del modelo

# %%
mse = mean_squared_error(y_test_reg, y_pred_reg)
rmse = np.sqrt(mse)
r2 = r2_score(y_test_reg, y_pred_reg)

print(f"R² (Coeficiente de determinación): {r2:.4f}")
print(f"MSE (Error Cuadrático Medio):      {mse:.4f}")
print(f"RMSE (Raíz del MSE):               {rmse:.4f}")
print(f"\nEl modelo explica el {r2*100:.1f}% de la variabilidad en AvergePrice.")
# Out:
# R² (Coeficiente de determinación): 0.6498
# MSE (Error Cuadrático Medio):      0.3536
# RMSE (Raíz del MSE):               0.5947
#
# El modelo explica el 65.0% de la variabilidad en AvergePrice.

# %% [markdown]
# ## Ahora intentaremos usando solo el volumen total

# %%
X_reg = df[['type_ORGANIC','Total Volume','month','week'] 
    + list(region_dummies)]
y_reg = df['AveragePrice']

# Dividir en entrenamiento (80%) y prueba (20%)
X_train_reg, X_test_reg, y_train_reg, y_test_reg = train_test_split(
    X_reg, y_reg, test_size=0.2, random_state=42
)

print(f"Datos de entrenamiento: {X_train_reg.shape}")
print(f"Datos de prueba: {X_test_reg.shape}")
# Out:
# Datos de entrenamiento: (14347, 57)
# Datos de prueba: (3587, 57)

# %%
modelo_reg = LinearRegression()
modelo_reg.fit(X_train_reg, y_train_reg)

# Predecir sobre el conjunto de prueba
y_pred_reg = modelo_reg.predict(X_test_reg)

print(f"Coeficientes: {modelo_reg.coef_}")
print(f"Intercepto: {modelo_reg.intercept_:.4f}")
print(f"\nInterpretación:")
for col, coef in zip(X_reg.columns, modelo_reg.coef_):
    print(f"  {col}: {coef:+.4f} (por cada unidad de aumento, AvegarePrice cambia en {coef:+.4f})")
# Out:
# Coeficientes: [-0.48812456 -1.11081799  0.0525123  -0.00521406  0.19817445  1.0062924
#  -0.60938771  0.77946062  0.13632944  1.60926507  0.54989632  1.0829303
#  -0.17079004 -0.32943947 -0.09316235  0.29660115  0.06862812 -0.02092488
#   1.27241957  0.41148834  1.23522109 -0.16653389 -0.34418017  0.08819506
#   0.11131597  0.81597664 -0.61309565  0.16229011  1.37221892 -0.32376348
#  -0.29035557  1.76507457  1.9993852   0.58392151  0.38437381  0.95669658
#   0.10711125 -0.30015654  1.14463657  0.36643508  0.5032056  -0.09589874
#  -0.37295392  0.87752477  0.44528201  1.4108285   0.67770459  0.24204771
#   0.74004667  1.29426576 -0.32086181  0.0726308  -0.1723424   0.02650562
#   2.27343431  1.39829008  0.19783091]
# Intercepto: -0.3992
#
# Interpretación:
#   type_ORGANIC: -0.4881 (por cada unidad de aumento, AvegarePrice cambia en -0.4881)
#   Total Volume: -1.1108 (por cada unidad de aumento, AvegarePrice cambia en -1.1108)
#   month: +0.0525 (por cada unidad de aumento, AvegarePrice cambia en +0.0525)
#   week: -0.0052 (por cada unidad de aumento, AvegarePrice cambia en -0.0052)
#   region_ATLANTA: +0.1982 (por cada unidad de aumento, AvegarePrice cambia en +0.1982)
#   region_BALTIMOREWASHINGTON: +1.0063 (por cada unidad de aumento, AvegarePrice cambia en +1.0063)
#   region_BOISE: -0.6094 (por cada unidad de aumento, AvegarePrice cambia en -0.6094)
#   region_BOSTON: +0.7795 (por cada unidad de aumento, AvegarePrice cambia en +0.7795)
#   region_BUFFALOROCHESTER: +0.1363 (por cada unidad de aumento, AvegarePrice cambia en +0.1363)
#   region_CALIFORNIA: +1.6093 (por cada unidad de aumento, AvegarePrice cambia en +1.6093)
#   region_CHARLOTTE: +0.5499 (por cada unidad de aumento, AvegarePrice cambia en +0.5499)
#   region_CHICAGO: +1.0829 (por cada unidad de aumento, AvegarePrice cambia en +1.0829)
#   region_CINCINNATIDAYTON: -0.1708 (por cada unidad de aumento, AvegarePrice cambia en -0.1708)
#   region_COLUMBUS: -0.3294 (por cada unidad de aumento, AvegarePrice cambia en -0.3294)
#   region_DALLASFTWORTH: -0.0932 (por cada unidad de aumento, AvegarePrice cambia en -0.0932)
#   region_DENVER: +0.2966 (por cada unidad de aumento, AvegarePrice cambia en +0.2966)
#   region_DETROIT: +0.0686 (por cada unidad de aumento, AvegarePrice cambia en +0.0686)
#   region_GRANDRAPIDS: -0.0209 (por cada unidad de aumento, AvegarePrice cambia en -0.0209)
#   region_GREATLAKES: +1.2724 (por cada unidad de aumento, AvegarePrice cambia en +1.2724)
#   region_HARRISBURGSCRANTON: +0.4115 (por cada unidad de aumento, AvegarePrice cambia en +0.4115)
#   region_HARTFORDSPRINGFIELD: +1.2352 (por cada unidad de aumento, AvegarePrice cambia en +1.2352)
#   region_HOUSTON: -0.1665 (por cada unidad de aumento, AvegarePrice cambia en -0.1665)
#   region_INDIANAPOLIS: -0.3442 (por cada unidad de aumento, AvegarePrice cambia en -0.3442)
#   region_JACKSONVILLE: +0.0882 (por cada unidad de aumento, AvegarePrice cambia en +0.0882)
#   region_LASVEGAS: +0.1113 (por cada unidad de aumento, AvegarePrice cambia en +0.1113)
#   region_LOSANGELES: +0.8160 (por cada unidad de aumento, AvegarePrice cambia en +0.8160)
#   region_LOUISVILLE: -0.6131 (por cada unidad de aumento, AvegarePrice cambia en -0.6131)
#   region_MIAMIFTLAUDERDALE: +0.1623 (por cada unidad de aumento, AvegarePrice cambia en +0.1623)
#   region_MIDSOUTH: +1.3722 (por cada unidad de aumento, AvegarePrice cambia en +1.3722)
#   region_NASHVILLE: -0.3238 (por cada unidad de aumento, AvegarePrice cambia en -0.3238)
#   region_NEWORLEANSMOBILE: -0.2904 (por cada unidad de aumento, AvegarePrice cambia en -0.2904)
#   region_NEWYORK: +1.7651 (por cada unidad de aumento, AvegarePrice cambia en +1.7651)
#   region_NORTHEAST: +1.9994 (por cada unidad de aumento, AvegarePrice cambia en +1.9994)
#   region_NORTHERNNEWENGLAND: +0.5839 (por cada unidad de aumento, AvegarePrice cambia en +0.5839)
#   region_ORLANDO: +0.3844 (por cada unidad de aumento, AvegarePrice cambia en +0.3844)
#   region_PHILADELPHIA: +0.9567 (por cada unidad de aumento, AvegarePrice cambia en +0.9567)
#   region_PHOENIXTUCSON: +0.1071 (por cada unidad de aumento, AvegarePrice cambia en +0.1071)
#   region_PITTSBURGH: -0.3002 (por cada unidad de aumento, AvegarePrice cambia en -0.3002)
#   region_PLAINS: +1.1446 (por cada unidad de aumento, AvegarePrice cambia en +1.1446)
#   region_PORTLAND: +0.3664 (por cada unidad de aumento, AvegarePrice cambia en +0.3664)
#   region_RALEIGHGREENSBORO: +0.5032 (por cada unidad de aumento, AvegarePrice cambia en +0.5032)
#   region_RICHMONDNORFOLK: -0.0959 (por cada unidad de aumento, AvegarePrice cambia en -0.0959)
#   region_ROANOKE: -0.3730 (por cada unidad de aumento, AvegarePrice cambia en -0.3730)
#   region_SACRAMENTO: +0.8775 (por cada unidad de aumento, AvegarePrice cambia en +0.8775)
#   region_SANDIEGO: +0.4453 (por cada unidad de aumento, AvegarePrice cambia en +0.4453)
#   region_SANFRANCISCO: +1.4108 (por cada unidad de aumento, AvegarePrice cambia en +1.4108)
#   region_SEATTLE: +0.6777 (por cada unidad de aumento, AvegarePrice cambia en +0.6777)
#   region_SOUTHCAROLINA: +0.2420 (por cada unidad de aumento, AvegarePrice cambia en +0.2420)
#   region_SOUTHCENTRAL: +0.7400 (por cada unidad de aumento, AvegarePrice cambia en +0.7400)
#   region_SOUTHEAST: +1.2943 (por cada unidad de aumento, AvegarePrice cambia en +1.2943)
#   region_SPOKANE: -0.3209 (por cada unidad de aumento, AvegarePrice cambia en -0.3209)
#   region_STLOUIS: +0.0726 (por cada unidad de aumento, AvegarePrice cambia en +0.0726)
#   region_SYRACUSE: -0.1723 (por cada unidad de aumento, AvegarePrice cambia en -0.1723)
#   region_TAMPA: +0.0265 (por cada unidad de aumento, AvegarePrice cambia en +0.0265)
#   region_TOTALUS: +2.2734 (por cada unidad de aumento, AvegarePrice cambia en +2.2734)
#   region_WEST: +1.3983 (por cada unidad de aumento, AvegarePrice cambia en +1.3983)
#   region_WESTTEXNEWMEXICO: +0.1978 (por cada unidad de aumento, AvegarePrice cambia en +0.1978)

# %% [markdown]
# ## Tabla comparativa

# %%
df_pred_reg = pd.DataFrame({
    'Actual': y_test_reg.values, 
    'Predicho': y_pred_reg.round(2), 
    'Error': (y_test_reg.values - y_pred_reg).round(4)
})
df_pred_reg.head(10)
# Out:
#      Actual  Predicho   Error
# 0  0.944418      1.24 -0.2998
# 1  0.021696      0.06 -0.0402
# 2  0.601692      0.52  0.0792
# 3 -0.452846     -0.45 -0.0044
# 4 -0.848298     -0.75 -0.1028
# 5 -0.321029     -0.52  0.2036
# 6  1.656231      1.47  0.1906
# 7 -1.006479     -0.64 -0.3691
# 8 -1.586476     -0.97 -0.6119
# 9  1.366233      1.61 -0.2408

# %% [markdown]
# ## Evaluación del modelo

# %%
mse = mean_squared_error(y_test_reg, y_pred_reg)
rmse = np.sqrt(mse)
r2 = r2_score(y_test_reg, y_pred_reg)

print(f"R² (Coeficiente de determinación): {r2:.4f}")
print(f"MSE (Error Cuadrático Medio):      {mse:.4f}")
print(f"RMSE (Raíz del MSE):               {rmse:.4f}")
print(f"\nEl modelo explica el {r2*100:.1f}% de la variabilidad en AvergePrice.")
# Out:
# R² (Coeficiente de determinación): 0.6375
# MSE (Error Cuadrático Medio):      0.3661
# RMSE (Raíz del MSE):               0.6050
#
# El modelo explica el 63.7% de la variabilidad en AvergePrice.

# %% [markdown]
# ## Ahora solo con las variables de volumen de manera independiente

# %%
X_reg = df[['type_ORGANIC','4046', '4225', '4770','month','week'] 
    + list(region_dummies)]
y_reg = df['AveragePrice']

# Dividir en entrenamiento (80%) y prueba (20%)
X_train_reg, X_test_reg, y_train_reg, y_test_reg = train_test_split(
    X_reg, y_reg, test_size=0.2, random_state=42
)

print(f"Datos de entrenamiento: {X_train_reg.shape}")
print(f"Datos de prueba: {X_test_reg.shape}")
# Out:
# Datos de entrenamiento: (14347, 59)
# Datos de prueba: (3587, 59)

# %%
modelo_reg = LinearRegression()
modelo_reg.fit(X_train_reg, y_train_reg)

# Predecir sobre el conjunto de prueba
y_pred_reg = modelo_reg.predict(X_test_reg)

print(f"Coeficientes: {modelo_reg.coef_}")
print(f"Intercepto: {modelo_reg.intercept_:.4f}")
print(f"\nInterpretación:")
for col, coef in zip(X_reg.columns, modelo_reg.coef_):
    print(f"  {col}: {coef:+.4f} (por cada unidad de aumento, AvegarePrice cambia en {coef:+.4f})")
# Out:
# Coeficientes: [ 1.00914048 -0.0410587  -0.01111868 -0.127689    0.05142661 -0.00286679
#  -0.53007442  0.13735984 -0.55389617 -0.01039607 -0.14825873 -0.21728232
#   0.28931511  0.0482009  -0.8102955  -0.66974467 -1.1330574  -0.68784453
#  -0.58677077 -0.15404646 -0.3845465  -0.02884643  0.68772025 -1.22021817
#  -0.58339369 -0.06656227 -0.43839385 -0.7010405  -0.64385792 -0.35587609
#  -0.11984499 -0.74645036 -0.62977295  0.59383144  0.3380942  -0.17079398
#  -0.09124884  0.29477384 -0.80151462 -0.42200621 -0.11307343 -0.59113494
#   0.08902843 -0.50499614 -0.77676274  0.30025321 -0.30504047  0.44138095
#  -0.35539676 -0.22125139 -1.01065072 -0.14558541 -0.3790903  -0.31091933
#  -0.14470447 -0.41735883 -0.25365132 -0.47028893 -0.63830775]
# Intercepto: -0.4378
#
# Interpretación:
#   type_ORGANIC: +1.0091 (por cada unidad de aumento, AvegarePrice cambia en +1.0091)
#   4046: -0.0411 (por cada unidad de aumento, AvegarePrice cambia en -0.0411)
#   4225: -0.0111 (por cada unidad de aumento, AvegarePrice cambia en -0.0111)
#   4770: -0.1277 (por cada unidad de aumento, AvegarePrice cambia en -0.1277)
#   month: +0.0514 (por cada unidad de aumento, AvegarePrice cambia en +0.0514)
#   week: -0.0029 (por cada unidad de aumento, AvegarePrice cambia en -0.0029)
#   region_ATLANTA: -0.5301 (por cada unidad de aumento, AvegarePrice cambia en -0.5301)
#   region_BALTIMOREWASHINGTON: +0.1374 (por cada unidad de aumento, AvegarePrice cambia en +0.1374)
#   region_BOISE: -0.5539 (por cada unidad de aumento, AvegarePrice cambia en -0.5539)
#   region_BOSTON: -0.0104 (por cada unidad de aumento, AvegarePrice cambia en -0.0104)
#   region_BUFFALOROCHESTER: -0.1483 (por cada unidad de aumento, AvegarePrice cambia en -0.1483)
#   region_CALIFORNIA: -0.2173 (por cada unidad de aumento, AvegarePrice cambia en -0.2173)
#   region_CHARLOTTE: +0.2893 (por cada unidad de aumento, AvegarePrice cambia en +0.2893)
#   region_CHICAGO: +0.0482 (por cada unidad de aumento, AvegarePrice cambia en +0.0482)
#   region_CINCINNATIDAYTON: -0.8103 (por cada unidad de aumento, AvegarePrice cambia en -0.8103)
#   region_COLUMBUS: -0.6697 (por cada unidad de aumento, AvegarePrice cambia en -0.6697)
#   region_DALLASFTWORTH: -1.1331 (por cada unidad de aumento, AvegarePrice cambia en -1.1331)
#   region_DENVER: -0.6878 (por cada unidad de aumento, AvegarePrice cambia en -0.6878)
#   region_DETROIT: -0.5868 (por cada unidad de aumento, AvegarePrice cambia en -0.5868)
#   region_GRANDRAPIDS: -0.1540 (por cada unidad de aumento, AvegarePrice cambia en -0.1540)
#   region_GREATLAKES: -0.3845 (por cada unidad de aumento, AvegarePrice cambia en -0.3845)
#   region_HARRISBURGSCRANTON: -0.0288 (por cada unidad de aumento, AvegarePrice cambia en -0.0288)
#   region_HARTFORDSPRINGFIELD: +0.6877 (por cada unidad de aumento, AvegarePrice cambia en +0.6877)
#   region_HOUSTON: -1.2202 (por cada unidad de aumento, AvegarePrice cambia en -1.2202)
#   region_INDIANAPOLIS: -0.5834 (por cada unidad de aumento, AvegarePrice cambia en -0.5834)
#   region_JACKSONVILLE: -0.0666 (por cada unidad de aumento, AvegarePrice cambia en -0.0666)
#   region_LASVEGAS: -0.4384 (por cada unidad de aumento, AvegarePrice cambia en -0.4384)
#   region_LOSANGELES: -0.7010 (por cada unidad de aumento, AvegarePrice cambia en -0.7010)
#   region_LOUISVILLE: -0.6439 (por cada unidad de aumento, AvegarePrice cambia en -0.6439)
#   region_MIAMIFTLAUDERDALE: -0.3559 (por cada unidad de aumento, AvegarePrice cambia en -0.3559)
#   region_MIDSOUTH: -0.1198 (por cada unidad de aumento, AvegarePrice cambia en -0.1198)
#   region_NASHVILLE: -0.7465 (por cada unidad de aumento, AvegarePrice cambia en -0.7465)
#   region_NEWORLEANSMOBILE: -0.6298 (por cada unidad de aumento, AvegarePrice cambia en -0.6298)
#   region_NEWYORK: +0.5938 (por cada unidad de aumento, AvegarePrice cambia en +0.5938)
#   region_NORTHEAST: +0.3381 (por cada unidad de aumento, AvegarePrice cambia en +0.3381)
#   region_NORTHERNNEWENGLAND: -0.1708 (por cada unidad de aumento, AvegarePrice cambia en -0.1708)
#   region_ORLANDO: -0.0912 (por cada unidad de aumento, AvegarePrice cambia en -0.0912)
#   region_PHILADELPHIA: +0.2948 (por cada unidad de aumento, AvegarePrice cambia en +0.2948)
#   region_PHOENIXTUCSON: -0.8015 (por cada unidad de aumento, AvegarePrice cambia en -0.8015)
#   region_PITTSBURGH: -0.4220 (por cada unidad de aumento, AvegarePrice cambia en -0.4220)
#   region_PLAINS: -0.1131 (por cada unidad de aumento, AvegarePrice cambia en -0.1131)
#   region_PORTLAND: -0.5911 (por cada unidad de aumento, AvegarePrice cambia en -0.5911)
#   region_RALEIGHGREENSBORO: +0.0890 (por cada unidad de aumento, AvegarePrice cambia en +0.0890)
#   region_RICHMONDNORFOLK: -0.5050 (por cada unidad de aumento, AvegarePrice cambia en -0.5050)
#   region_ROANOKE: -0.7768 (por cada unidad de aumento, AvegarePrice cambia en -0.7768)
#   region_SACRAMENTO: +0.3003 (por cada unidad de aumento, AvegarePrice cambia en +0.3003)
#   region_SANDIEGO: -0.3050 (por cada unidad de aumento, AvegarePrice cambia en -0.3050)
#   region_SANFRANCISCO: +0.4414 (por cada unidad de aumento, AvegarePrice cambia en +0.4414)
#   region_SEATTLE: -0.3554 (por cada unidad de aumento, AvegarePrice cambia en -0.3554)
#   region_SOUTHCAROLINA: -0.2213 (por cada unidad de aumento, AvegarePrice cambia en -0.2213)
#   region_SOUTHCENTRAL: -1.0107 (por cada unidad de aumento, AvegarePrice cambia en -1.0107)
#   region_SOUTHEAST: -0.1456 (por cada unidad de aumento, AvegarePrice cambia en -0.1456)
#   region_SPOKANE: -0.3791 (por cada unidad de aumento, AvegarePrice cambia en -0.3791)
#   region_STLOUIS: -0.3109 (por cada unidad de aumento, AvegarePrice cambia en -0.3109)
#   region_SYRACUSE: -0.1447 (por cada unidad de aumento, AvegarePrice cambia en -0.1447)
#   region_TAMPA: -0.4174 (por cada unidad de aumento, AvegarePrice cambia en -0.4174)
#   region_TOTALUS: -0.2537 (por cada unidad de aumento, AvegarePrice cambia en -0.2537)
#   region_WEST: -0.4703 (por cada unidad de aumento, AvegarePrice cambia en -0.4703)
#   region_WESTTEXNEWMEXICO: -0.6383 (por cada unidad de aumento, AvegarePrice cambia en -0.6383)

# %% [markdown]
# ## Tabla comparativa

# %%
df_pred_reg = pd.DataFrame({
    'Actual': y_test_reg.values, 
    'Predicho': y_pred_reg.round(2), 
    'Error': (y_test_reg.values - y_pred_reg).round(4)
})
df_pred_reg.head(10)
# Out:
#      Actual  Predicho   Error
# 0  0.944418      1.20 -0.2577
# 1  0.021696      0.18 -0.1601
# 2  0.601692      0.74 -0.1411
# 3 -0.452846     -0.85  0.3956
# 4 -0.848298     -0.71 -0.1335
# 5 -0.321029      0.07 -0.3905
# 6  1.656231      1.29  0.3658
# 7 -1.006479     -0.59 -0.4120
# 8 -1.586476     -1.04 -0.5482
# 9  1.366233      0.95  0.4145

# %% [markdown]
# ## Evaluación del modelo

# %%
mse = mean_squared_error(y_test_reg, y_pred_reg)
rmse = np.sqrt(mse)
r2 = r2_score(y_test_reg, y_pred_reg)

print(f"R² (Coeficiente de determinación): {r2:.4f}")
print(f"MSE (Error Cuadrático Medio):      {mse:.4f}")
print(f"RMSE (Raíz del MSE):               {rmse:.4f}")
print(f"\nEl modelo explica el {r2*100:.1f}% de la variabilidad en AvergePrice.")
# Out:
# R² (Coeficiente de determinación): 0.5901
# MSE (Error Cuadrático Medio):      0.4140
# RMSE (Raíz del MSE):               0.6434
#
# El modelo explica el 59.0% de la variabilidad en AvergePrice.

# %% [markdown]
# ## Por ultimo intentamos sin las variables dummies de las regiones

# %%
X_reg = df[['type_ORGANIC', '4046', '4225', '4770','month','week']] 
y_reg = df['AveragePrice']

# Dividir en entrenamiento (80%) y prueba (20%)
X_train_reg, X_test_reg, y_train_reg, y_test_reg = train_test_split(
    X_reg, y_reg, test_size=0.2, random_state=42
)

print(f"Datos de entrenamiento: {X_train_reg.shape}")
print(f"Datos de prueba: {X_test_reg.shape}")
# Out:
# Datos de entrenamiento: (14347, 6)
# Datos de prueba: (3587, 6)

# %%
modelo_reg = LinearRegression()
modelo_reg.fit(X_train_reg, y_train_reg)

# Predecir sobre el conjunto de prueba
y_pred_reg = modelo_reg.predict(X_test_reg)

print(f"Coeficientes: {modelo_reg.coef_}")
print(f"Intercepto: {modelo_reg.intercept_:.4f}")
print(f"\nInterpretación:")
for col, coef in zip(X_reg.columns, modelo_reg.coef_):
    print(f"  {col}: {coef:+.4f} (por cada unidad de aumento, AvegarePrice cambia en {coef:+.4f})")
# Out:
# Coeficientes: [ 1.08444025 -0.28357397  0.16782103 -0.02437797  0.05251261 -0.00322   ]
# Intercepto: -0.7813
#
# Interpretación:
#   type_ORGANIC: +1.0844 (por cada unidad de aumento, AvegarePrice cambia en +1.0844)
#   4046: -0.2836 (por cada unidad de aumento, AvegarePrice cambia en -0.2836)
#   4225: +0.1678 (por cada unidad de aumento, AvegarePrice cambia en +0.1678)
#   4770: -0.0244 (por cada unidad de aumento, AvegarePrice cambia en -0.0244)
#   month: +0.0525 (por cada unidad de aumento, AvegarePrice cambia en +0.0525)
#   week: -0.0032 (por cada unidad de aumento, AvegarePrice cambia en -0.0032)

# %% [markdown]
# ## Tabla comparativa

# %%
df_pred_reg = pd.DataFrame({
    'Actual': y_test_reg.values, 
    'Predicho': y_pred_reg.round(2), 
    'Error': (y_test_reg.values - y_pred_reg).round(4)
})
df_pred_reg.head(10)
# Out:
#      Actual  Predicho   Error
# 0  0.944418      0.82  0.1195
# 1  0.021696      0.33 -0.3053
# 2  0.601692      0.62 -0.0185
# 3 -0.452846     -0.80  0.3481
# 4 -0.848298     -0.88  0.0271
# 5 -0.321029      0.61 -0.9264
# 6  1.656231      0.53  1.1237
# 7 -1.006479     -0.13 -0.8803
# 8 -1.586476     -0.87 -0.7165
# 9  1.366233      0.72  0.6499

# %% [markdown]
# ## Evaluación del modelo

# %%
mse = mean_squared_error(y_test_reg, y_pred_reg)
rmse = np.sqrt(mse)
r2 = r2_score(y_test_reg, y_pred_reg)

print(f"R² (Coeficiente de determinación): {r2:.4f}")
print(f"MSE (Error Cuadrático Medio):      {mse:.4f}")
print(f"RMSE (Raíz del MSE):               {rmse:.4f}")
print(f"\nEl modelo explica el {r2*100:.1f}% de la variabilidad en AvergePrice.")
# Out:
# R² (Coeficiente de determinación): 0.4520
# MSE (Error Cuadrático Medio):      0.5533
# RMSE (Raíz del MSE):               0.7439
#
# El modelo explica el 45.2% de la variabilidad en AvergePrice.

# %% [markdown]
# ### Conclusión
# ## El modelo no tiene forma de tener una buena precisión en su predicción ya que la baja correlación de las variables con el precio impide tener buenas estimaciones
